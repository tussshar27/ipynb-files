# %%
print('Hello')
# Out:
# Hello

# %%
import pandas as pd

# %%
d1 = pd.read_csv("G:/TUSHAR ANNAM/Python/datawithdarshil_python-for-data-engineering-main/python-for-data-engineering-main/4. Python Advance/data/weather_2012.csv")
d1
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                   4              8.0           101.24                   Fog
# 1                   4              8.0           101.24                   Fog
# 2                   7              4.0           101.26  Freezing Drizzle,Fog
# 3                   6              4.0           101.27  Freezing Drizzle,Fog
# 4                   7              4.8           101.23                   Fog
# ...               ...              ...              ...                   ...
# 8779               30              9.7           100.13                  Snow
# 8780               24              9.7           100.03                  Snow
# 8781               28              4.8            99.95                  Snow
# 8782               28              9.7            99.91                  Snow
# 8783               30             11.3            99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
d1['Visibility (km)'].head()
# Out:
# 0    8.0
# 1    8.0
# 2    4.0
# 3    4.0
# 4    4.8
# Name: Visibility (km), dtype: float64

# %%
d1['Visibility (km)'].head() + 5
# Out:
# 0    13.0
# 1    13.0
# 2     9.0
# 3     9.0
# 4     9.8
# Name: Visibility (km), dtype: float64

# %%
#new column is created.

d1['new_temp_col'] = d1['Temp (C)'] + d1['Dew Point Temp (C)']

# %%
d1.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    new_temp_col
# 0          -5.7
# 1          -5.5
# 2          -5.2
# 3          -4.7
# 4          -4.8

# %% [markdown]
# .apply() function
#
# If we want to apply any logic then we first create a function for storing that logic and then we pass that function in apply function.

# %%
def times2(value):
    return value * 2

# %%
d1['Visibility (km)'].head()
# Out:
# 0    8.0
# 1    8.0
# 2    4.0
# 3    4.0
# 4    4.8
# Name: Visibility (km), dtype: float64

# %%
d1['Visibility (km)'].apply(times2).head()
# Out:
# 0    16.0
# 1    16.0
# 2     8.0
# 3     8.0
# 4     9.6
# Name: Visibility (km), dtype: float64

# %% [markdown]
# .describe() function

# %%
d1['Visibility (km)'].describe()
# Out:
# count    8784.000000
# mean       27.664447
# std        12.622688
# min         0.200000
# 25%        24.100000
# 50%        25.000000
# 75%        25.000000
# max        48.300000
# Name: Visibility (km), dtype: float64

# %% [markdown]
# Adding / Updating Columns

# %%
#Q. Update value of Visibility by multiplying into 1000
updated_visibility = d1['Visibility (km)'] * 1000   #good practice to store it in a variable
d1['Visibility (km)'] = updated_visibility

# %%
d1['Visibility (km)'].head()
# Out:
# 0    8000000.0
# 1    8000000.0
# 2    4000000.0
# 3    4000000.0
# 4    4800000.0
# Name: Visibility (km), dtype: float64

# %% [markdown]
# .rename() function
# renaming columns in dataframe

# %%
d1.rename(columns={'Visibility (km)': 'Visibility (kilometer)'}, inplace=True)  #if we want to store it in variable then we will remove inplace parameter.
d1
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (kilometer)  Stn Press (kPa)  \
# 0                   4               8000000.0           101.24
# 1                   4               8000000.0           101.24
# 2                   7               4000000.0           101.26
# 3                   6               4000000.0           101.27
# 4                   7               4800000.0           101.23
# ...               ...                     ...              ...
# 8779               30               9700000.0           100.13
# 8780               24               9700000.0           100.03
# 8781               28               4800000.0            99.95
# 8782               28               9700000.0            99.91
# 8783               30              11300000.0            99.89
#
#                    Weather  new_temp_col
# 0                      Fog          -5.7
# 1                      Fog          -5.5
# 2     Freezing Drizzle,Fog          -5.2
# 3     Freezing Drizzle,Fog          -4.7
# 4                      Fog          -4.8
# ...                    ...           ...
# 8779                  Snow          -2.6
# 8780                  Snow          -2.2
# 8781                  Snow          -2.0
# 8782                  Snow          -2.0
# 8783                  Snow          -2.1
#
# [8784 rows x 9 columns]

# %% [markdown]
# .drop() function
# used to drop column(s) of a dataframe

# %%
d1.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (kilometer)  Stn Press (kPa)  \
# 0                4               8000000.0           101.24
# 1                4               8000000.0           101.24
# 2                7               4000000.0           101.26
# 3                6               4000000.0           101.27
# 4                7               4800000.0           101.23
#
#                 Weather  new_temp_col
# 0                   Fog          -5.7
# 1                   Fog          -5.5
# 2  Freezing Drizzle,Fog          -5.2
# 3  Freezing Drizzle,Fog          -4.7
# 4                   Fog          -4.8

# %%
#axis: 0 means row, 1 means column
d1 = d1.drop(labels=['Temp (C)'],axis=1)
d1
# Out:
#                 Date/Time  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 0     2012-01-01 00:00:00                -3.9           86                4
# 1     2012-01-01 01:00:00                -3.7           87                4
# 2     2012-01-01 02:00:00                -3.4           89                7
# 3     2012-01-01 03:00:00                -3.2           88                6
# 4     2012-01-01 04:00:00                -3.3           88                7
# ...                   ...                 ...          ...              ...
# 8779  2012-12-31 19:00:00                -2.7           81               30
# 8780  2012-12-31 20:00:00                -2.4           83               24
# 8781  2012-12-31 21:00:00                -1.5           93               28
# 8782  2012-12-31 22:00:00                -1.8           89               28
# 8783  2012-12-31 23:00:00                -2.1           86               30
#
#       Visibility (km)  Stn Press (kPa)               Weather
# 0                 8.0           101.24                   Fog
# 1                 8.0           101.24                   Fog
# 2                 4.0           101.26  Freezing Drizzle,Fog
# 3                 4.0           101.27  Freezing Drizzle,Fog
# 4                 4.8           101.23                   Fog
# ...               ...              ...                   ...
# 8779              9.7           100.13                  Snow
# 8780              9.7           100.03                  Snow
# 8781              4.8            99.95                  Snow
# 8782              9.7            99.91                  Snow
# 8783             11.3            99.89                  Snow
#
# [8784 rows x 7 columns]

# %% [markdown]
# .sort_values() function

# %%
d1.head()
# Out:
#              Date/Time  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 0  2012-01-01 00:00:00                -3.9           86                4
# 1  2012-01-01 01:00:00                -3.7           87                4
# 2  2012-01-01 02:00:00                -3.4           89                7
# 3  2012-01-01 03:00:00                -3.2           88                6
# 4  2012-01-01 04:00:00                -3.3           88                7
#
#    Visibility (km)  Stn Press (kPa)               Weather
# 0              8.0           101.24                   Fog
# 1              8.0           101.24                   Fog
# 2              4.0           101.26  Freezing Drizzle,Fog
# 3              4.0           101.27  Freezing Drizzle,Fog
# 4              4.8           101.23                   Fog

# %%
sorted_visibility = d1.sort_values('Visibility (km)', ascending=False)
sorted_visibility
# Out:
#                 Date/Time  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 3974  2012-06-14 14:00:00                 5.5           33               15
# 2298  2012-04-05 18:00:00                -7.0           37               20
# 2311  2012-04-06 07:00:00                -8.9           50               15
# 2312  2012-04-06 08:00:00                -8.8           48               19
# 2313  2012-04-06 09:00:00                -8.4           46               17
# ...                   ...                 ...          ...              ...
# 1828  2012-03-17 04:00:00                 0.1           99                0
# 1830  2012-03-17 06:00:00                -0.4           98                4
# 1834  2012-03-17 10:00:00                 2.6          100                0
# 1833  2012-03-17 09:00:00                 1.5           99                4
# 1831  2012-03-17 07:00:00                 0.4           99                0
#
#       Visibility (km)  Stn Press (kPa)        Weather
# 3974             48.3           102.17          Clear
# 2298             48.3           100.75  Mostly Cloudy
# 2311             48.3           101.30          Clear
# 2312             48.3           101.34          Clear
# 2313             48.3           101.37          Clear
# ...               ...              ...            ...
# 1828              0.2           102.15            Fog
# 1830              0.2           102.26   Freezing Fog
# 1834              0.2           102.37            Fog
# 1833              0.2           102.38            Fog
# 1831              0.2           102.34            Fog
#
# [8784 rows x 7 columns]

# %%
#Q. Which were the top 10 hottest values and their counts?
d1.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
r = d1['Temp (C)'].value_counts().sort_values(ascending=False)
r.loc[:10]
# Out:
#  16.6    65
#  1.1     58
#  0.8     47
#  1.5     45
#  19.3    44
#          ..
#  25.9    17
#  6.4     17
#  24.0    17
# -6.8     17
#  10.0    17
# Name: Temp (C), Length: 256, dtype: int64
